# %% [markdown]
# <a href="https://colab.research.google.com/github/rb4050/DEEP_LEARING_CLG/blob/main/EXP_SIX__6___.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import libraries
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Step 2: Load IMDB dataset (Top 10,000 words only)
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# Step 3: Pad sequences so all reviews have same length
x_train = pad_sequences(x_train, maxlen=200)
x_test = pad_sequences(x_test, maxlen=200)

# Step 4: Build LSTM model
model = Sequential([
    Embedding(10000, 32),     # Converts word index to vector
    LSTM(64),                 # LSTM layer learns text pattern
    Dense(1, activation="sigmoid") # Output: 1 neuron (positive/negative)
])

# Step 5: Compile model
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# Step 6: Train model
model.fit(x_train, y_train, epochs=3, batch_size=64, validation_split=0.2)

# Step 7: Evaluate
loss, acc = model.evaluate(x_test, y_test)
print("✅ Test Accuracy:", acc)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 50s 148ms/step - accuracy: 0.6730 - loss: 0.5700 - val_accuracy: 0.8672 - val_loss: 0.3242
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 82s 147ms/step - accuracy: 0.8954 - loss: 0.2632 - val_accuracy: 0.8744 - val_loss: 0.3022
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 143ms/step - accuracy: 0.9319 - loss: 0.1890 - val_accuracy: 0.8738 - val_loss: 0.3145
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.8665 - loss: 0.3372
# ✅ Test Accuracy: 0.8669599890708923

# %%
for i in range(5):
  decoded=decode_review(x_test[i])
  pred=model.predict(x_test[i].reshape(1,200))[0][0]
  sentiment="Positive" if pred>0.5 else "Negative"
  actual="Positive" if y_test[i]==1 else "Negative"
  print(f"Review{i+1}")
  print(decoded)
  print("Predicted:",sentiment)
  print("Actual:",actual)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Review1
# ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? please give this one a miss br br ? ? and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite ? so all you madison fans give this a miss
# Predicted: Negative
# Actual: Negative
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Review2
# ...
